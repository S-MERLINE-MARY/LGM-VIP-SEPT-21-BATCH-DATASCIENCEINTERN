# %% [markdown]
# <a href="https://colab.research.google.com/github/S-MERLINE-MARY/LGM-VIP-SEPT-21-BATCH-DATASCIENCEINTERN/blob/main/Task4_datascienceintern_datascienceintern_LGMVIP_SEPT'21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LetsGrowMore** -
# LGM Virtual Internship Program 2021
#
# NAME : MERLINE MARY S
#
# DATA ANALYTICS INTERNSHIP
#
# TASK-4: [Intermediate Level]: Prediction using Decision Tree Algorithm
#
# DATE:27/09/2021

# %%
#Loading the required Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the data
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-26187a39-9e35-49a0-841e-cc6b5ff54d3d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26187a39-9e35-49a0-841e-cc6b5ff54d3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris (1).csv to Iris (1) (4).csv

# %%
df=pd.read_csv("Iris (1).csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [5 rows x 6 columns]

# %%
df.shape
# Out:
# (150, 6)

# %%
df.groupby('Species').count()
# Out:
#                  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa      50             50            50             50            50
# Iris-versicolor  50             50            50             50            50
# Iris-virginica   50             50            50             50            50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # **Visualization**

# %%
# Splitting of data
from sklearn.model_selection import train_test_split
Predictors=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
X=df[Predictors]
y=df.Species
print(X.head())
print(y.head())
X_train,X_val,y_train,y_val = train_test_split(X, y, random_state=0)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
#Scatter plot
import seaborn as sns
plt.figure(figsize=(10,10))
sns.scatterplot(data=X,alpha=0.9)
plt.title("Data_Attributes",size=15)
plt.show()

# %%
#correlation map
plt.figure(figsize=(7,7))
hm=X.corr()
sns.heatmap(hm,annot=True)
plt.title("Correlation map")
# Out:
# Text(0.5, 1.0, 'Correlation map')

# %% [markdown]
# # *modelling & fitting*

# %%
# Defining the model
from sklearn.tree import DecisionTreeClassifier
Tree=DecisionTreeClassifier(criterion='entropy',max_depth=4)
Tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=4, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# # *Prediction*

# %%
Predictions=Tree.predict(X_val)
pd.DataFrame({'Actual':y_val,'Predicted':Predictions})
# Out:
#               Actual        Predicted
# 114   Iris-virginica   Iris-virginica
# 62   Iris-versicolor  Iris-versicolor
# 33       Iris-setosa      Iris-setosa
# 107   Iris-virginica   Iris-virginica
# 7        Iris-setosa      Iris-setosa
# 100   Iris-virginica   Iris-virginica
# 40       Iris-setosa      Iris-setosa
# 86   Iris-versicolor  Iris-versicolor
# 76   Iris-versicolor  Iris-versicolor
# 71   Iris-versicolor  Iris-versicolor
# 134   Iris-virginica   Iris-virginica
# 51   Iris-versicolor  Iris-versicolor
# 73   Iris-versicolor  Iris-versicolor
# 54   Iris-versicolor  Iris-versicolor
# 63   Iris-versicolor  Iris-versicolor
# 37       Iris-setosa      Iris-setosa
# 78   Iris-versicolor  Iris-versicolor
# 90   Iris-versicolor  Iris-versicolor
# 45       Iris-setosa      Iris-setosa
# 16       Iris-setosa      Iris-setosa
# 121   Iris-virginica   Iris-virginica
# 66   Iris-versicolor  Iris-versicolor
# 24       Iris-setosa      Iris-setosa
# 8        Iris-setosa      Iris-setosa
# ...

# %% [markdown]
# # **Evaluation**

# %%
from sklearn import metrics
print('Accuracy:',metrics.accuracy_score(y_val,Predictions))
# Out:
# Accuracy: 0.9736842105263158

# %%
metrics.confusion_matrix(y_val,Predictions)
# Out:
# array([[13,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  9]])

# %% [markdown]
# **Visualization of the model**

# %%
from sklearn import tree

# %%
Predictors
# Out:
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %%
target=df.Species.unique()
target
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(Tree, feature_names=Predictors, class_names=target, filled=True)
# Out:
# [Text(334.8, 489.24, 'PetalLengthCm <= 2.35\nentropy = 1.581\nsamples = 112\nvalue = [37, 34, 41]\nclass = Iris-virginica'),
#  Text(251.10000000000002, 380.52000000000004, 'entropy = 0.0\nsamples = 37\nvalue = [37, 0, 0]\nclass = Iris-setosa'),
#  Text(418.5, 380.52000000000004, 'PetalLengthCm <= 4.95\nentropy = 0.994\nsamples = 75\nvalue = [0, 34, 41]\nclass = Iris-virginica'),
#  Text(167.4, 271.8, 'PetalWidthCm <= 1.65\nentropy = 0.414\nsamples = 36\nvalue = [0, 33, 3]\nclass = Iris-versicolor'),
#  Text(83.7, 163.08000000000004, 'entropy = 0.0\nsamples = 32\nvalue = [0, 32, 0]\nclass = Iris-versicolor'),
#  Text(251.10000000000002, 163.08000000000004, 'SepalWidthCm <= 3.1\nentropy = 0.811\nsamples = 4\nvalue = [0, 1, 3]\nclass = Iris-virginica'),
#  Text(167.4, 54.360000000000014, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = Iris-virginica'),
#  Text(334.8, 54.360000000000014, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Iris-versicolor'),
# ...

# %% [markdown]
# # **THANK YOU AMAN SIR & LETSGROWMORE COMMUNITY**
