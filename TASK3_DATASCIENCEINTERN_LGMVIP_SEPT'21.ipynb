# %% [markdown]
# <a href="https://colab.research.google.com/github/S-MERLINE-MARY/LGM-VIP-SEPT-21-BATCH-DATASCIENCEINTERN/blob/main/TASK3_DATASCIENCEINTERN_LGMVIP_SEPT'21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LetsGrowMore** -
# LGM Virtual Internship Program 2021
#
# NAME : MERLINE MARY S
#
# DATA ANALYTICS INTERNSHIP
#
# TASK-3: BEGINNERS LEVEL : Image to Pencil Sketch with Python
#
# DATE:27/09/2021

# %%
#Importing required libraries
from google.colab.patches import cv2_imshow
import cv2

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-cab9b490-2463-42ee-85a3-a6753e8fcf81" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cab9b490-2463-42ee-85a3-a6753e8fcf81">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving gandhijii.jpg to gandhijii (1).jpg

# %%
import matplotlib.image as mpimg
img=mpimg.imread("gandhijii.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=573x900 at 0x7F71C5E4FD90>

# %%
#Converting an image into gray_scale image
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=573x900 at 0x7F71C5E36790>

# %%
#Inverting the image

img_invert = cv2.bitwise_not(img_gray)

cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=573x900 at 0x7F71C5DD9250>

# %%
#Smoothing the image 
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=573x900 at 0x7F71C5DD9B50>

# %%
#obtaining final sketch
def dodgeV2(x, y):

    return cv2.divide(x, 255 - y, scale=256)

# %%
#Final Output as Pencil Sketch

final_img = dodgeV2(img_gray, img_smoothing)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=573x900 at 0x7F71C5E4A710>

# %% [markdown]
# # **THANK YOU AMAN KESARWANI SIR AND LETSGROWMORE COMMUNITY**
