# %% [markdown]
# <a href="https://colab.research.google.com/github/S-MERLINE-MARY/LGM-VIP-SEPT-21-BATCH-DATASCIENCEINTERN/blob/main/TASK3-DATASCIENCEINTERN-BEGINNERS%20LEVEL-LGMVIP-SEPT'21%20BATCH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LetsGrowMore** -
# LGM Virtual Internship Program 2021
#
# NAME : MERLINE MARY S
#
# DATA ANALYTICS INTERNSHIP
#
# TASK-4: BEGINNERS LEVEL : Image to Pencil Sketch with Python
#
# DATE:27/09/2021

# %%
#Importing required libraries
from google.colab.patches import cv2_imshow
import cv2

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-8c084278-7c8a-4445-86b5-628a25059547" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c084278-7c8a-4445-86b5-628a25059547">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving facey.jpg to facey (1).jpg

# %%
import matplotlib.image as mpimg
img=mpimg.imread("facey.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=768x1299 at 0x7F71C5F38750>

# %%
#Converting an image into gray_scale image
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=768x1299 at 0x7F71C5F38D10>

# %%
#Inverting the image

img_invert = cv2.bitwise_not(img_gray)

cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=768x1299 at 0x7F71C5EDB410>

# %%
#Smoothing the image 
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=768x1299 at 0x7F71C5EDBF50>

# %%
#obtaining final sketch
def dodgeV2(x, y):

    return cv2.divide(x, 255 - y, scale=256)

# %%
#Final Output as Pencil Sketch

final_img = dodgeV2(img_gray, img_smoothing)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=768x1299 at 0x7F71C5EE2B10>

# %% [markdown]
# # **THANK YOU AMAN KESARWANI SIR AND LETSGROWMORE COMMUNITY**
